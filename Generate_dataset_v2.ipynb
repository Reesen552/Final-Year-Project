# %%
#imports
import cv2
from imutils import paths
import numpy as np
import math
import pandas as pd

# %%
def vid2frame(input_path,output_path):
    """Takes in a video and splits into frames; Returns number of frames created"""
    
    capture = cv2.VideoCapture(input_path)
    frameNr = 0
    
    totalFrames = capture.get(cv2.CAP_PROP_FRAME_COUNT)
    
    
    
    while capture.isOpened():
        ret, frame = capture.read()
        
        #if frame is read correctly ret is True
        if not ret:
            #print("Can't receive frame (stream end?). Exiting ...")
            break
        else:
            rotate_frame = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)          # Rotate frame
            crop_frame = rotate_frame[150:350, :]
        
            frame_name = 'frame_'+str(frameNr)+'.jpg'
            save_path = output_path +'/'+frame_name
            cv2.imwrite(save_path,crop_frame)
            frameNr = frameNr + 1

    return totalFrames

# %%
def getFileLabels(path,dataNames = ['frame1.jpeg','frame2.jpeg']):
    
    video_name = path.split('/')[-1]
    label = video_name.split('_')
    
    t = int(label[2].split('=')[-1])
    m = int(label[3].split('=')[-1])
    x = float(label[4].split('=')[-1])
    q = label[5].split('=')[-1]
    flow_type =  label[7].split('.')[0]

    data = {'filename': dataNames,
        't': t,
        'm': m,
        'x': x,
        'q': q,
        'flow':flow_type}

    return pd.DataFrame(data)

# %%
def frame2strip(input_path,strip_size,strip_x_location,output_frame_length,frame_name_start = 0):
    """Crops a full image into a strip"""
    frameNr =0
    out_frameNr = frame_name_start

    frame_names = os.listdir(input_path)
    frames_num = len(frame_names)  #number of frames in the video/directory
    

    possible_full_frames = math.floor(frames_num/(output_frame_length/strip_size))
    print(f'Can create {possible_full_frames} frames from video {frames_num}')

    #List to store generated file names
    dataNames = []


    for name in frame_names:
        path = input_path +'/'+ name
        frame = cv2.imread(path)
        strip = frame[20:, strip_x_location:strip_x_location +strip_size]

        if frameNr == 0 :
            output_frame = strip
            frameNr = frameNr +1
        else :
            output_frame = np.concatenate((output_frame,strip),axis=1)
            frameNr = frameNr +1

        if(frameNr == output_frame_length/strip_size):
            name = 'frame_'+str(out_frameNr)+'.jpg'
            cv2.imwrite(f'D:\Flow Videos\dataset\{name}', output_frame)
            dataNames.append(name) 
            out_frameNr = out_frameNr + 1 # change back to 1
            frameNr = 0

            if(out_frameNr == possible_full_frames + frame_name_start ):
                break

    
    return out_frameNr,dataNames

# %%
#Location of raw data
input_path = r'D:\Flow Videos\raw_data\regime_videos\\'
frame_output_path = r'D:\Flow Videos\full_frames\regime_videos\\'

regime_type_paths = os.listdir(input_path)
regime_types = [ i.split('_')[-1] for i in regime_type_paths ] #regime types
print(regime_types)

video_paths = []
frame_output_paths = []

for i in regime_type_paths:
    in_path = input_path + i
    out_path = frame_output_path + i

    video_names = os.listdir(in_path)
    
    video_paths.extend((in_path +'/'+ i) for i in video_names )
    frame_output_paths.extend((out_path +'/'+ i) for i in video_names )

#video_paths
# Out:
# ['bubbly', 'bubbly-slug', 'slug', 'slug-churn', 'churn', 'churn-annular', 'annular', 'mist']

# %%
#Split all videos into frames

# for i in range(len(video_paths)):
#     vid_path = video_paths[i]
#     out_path = output_paths[i]

#     os.makedirs(out_path, exist_ok=True)
#     vid2frame(vid_path,out_path)
#     print(f"Video {i} done")

# %%
#Parameters
strip_size = 2     # Width of strip in pixels
frames_req =  2500 - 1   # number of frames used (generates 1 extra hence -1)
strip_x_location = 1     # Horizontal loaction of strip start in pixels
output_frame_length = 1000  # Size of Output frame in pixels

# %%
frame_name_start = 0
labels = []

for i in range(len(frame_output_paths)):
    input_path = frame_output_paths[i]
    print(input_path)
    
    frame_name_start,dataNames = frame2strip(input_path,strip_size,strip_x_location,output_frame_length,frame_name_start)

    labels.append(getFileLabels(input_path,dataNames))

labels =pd.concat(labels)
#print(labels)
# Out:
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20201211_15.00_T=-25_mf=15_x=-0.0037_q=AD_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20201211_15.26_T=-25_mf=15_x=0.0049_q=AD_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20201215_16.41_T=-25_mf=10_x=0.0112_q=AD_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210120_17.03_T=+5_m=23_x=-0.0061_q=AD_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210127_15.50_T=+5_m=5_x=-0.0166_q=AD_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210128_15.58_T=+5_m=5_x=-0.0083_q=5000_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210128_16.25_T=+5_m=5_x=-0.0073_q=5000_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210128_16.56_T=+5_m=5_x=0.0048_q=5000_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210217_17.54_T=+5_m=23_x=-0.0033_q=11100_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210225_15.04_T=-5_m=20_x=-0.0074_q=11100_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210302_17.25_T=-5_m=20_x=-0.0055_q=5000_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210302_17.45_T=-5_m=20_x=0.0047_q=5000_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\1_bubbly/20210303_17.53_T=-7_m=10_x=0.0062_q=5000_up_bubbly.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20201215_17.07_T=-25_mf=10_x=0.0261_q=AD_up_bubbly_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20201215_17.26_T=-25_mf=10_x=0.0262_q=AD_up_bubbly_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210120_17.57_T=+5_m=23_x=-0.0063_q=AD_up_bubbly_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210120_18.45_T=+5_m=23_x=0.021_q=AD_up_bubbly-slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210120_18.54_T=+5_m=23_x=0.0311_q=AD_up_bubbly-slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210127_16.07_T=+5_m=5_x=-0.0072_q=AD_up_bubbly_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210127_16.33_T=+5_m=5_x=0.0031_q=AD_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210129_16.15_T=+5_m=15_x=-0.0011_q=AD_up_bubbly_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210204_20.19_T=+5_m=15_x=0.0177_q=5000_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210204_20.30_T=+5_m=15_x=0.0396_q=5000_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210204_20.45_T=+5_m=15_x=0.0887_q=5000_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210205_14.35_T=+5_m=15_x=0.0092_q=11100_up_bubbly_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210302_18.04_T=-5_m=20_x=0.0134_q=5000_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\2_bubbly-slug/20210302_18.15_T=-5_m=20_x=0.0233_q=5000_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20201211_16.00_T=-25_mf=15_x=0.013_q=AD_up_slug.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20201211_16.24_T=-25_mf=15_x=0.0233_q=AD_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20201211_16.49_T=-25_mf=15_x=0.0436_q=AD_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20201211_17.18_T=-25_mf=15_x=0.1039_q=AD_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20201215_17.49_T=-25_mf=10_x=0.0347_q=AD_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20210120_18.18_T=+5_m=23_x=0.0106_q=AD_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20210225_15.55_T=-5_m=20_x=0.0148_q=11100_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20210303_18.39_T=-7_m=10_x=0.0443_q=5000_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\3_slug/20210303_18.50_T=-7_m=10_x=0.0749_q=5000_up_slug_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\4_slug-churn/20201124_19.24_T=-15_mf=5_x=0.2904_q=AD_up_slug_churn_mp4_C001H001S0001.mp4
# Can create 7 frames from video 3883
# D:\Flow Videos\full_frames\regime_videos\\4_slug-churn/20201125_21.34_T=-15_mf=5_x=0.2312_q=5000_up_slug_churn_512x512_mp4_C001H001S0001.mp4
# Can create 4 frames from video 2184
# D:\Flow Videos\full_frames\regime_videos\\4_slug-churn/