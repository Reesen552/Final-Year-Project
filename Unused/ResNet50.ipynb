# %% [markdown]
# ### 1. Import dependencies

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

# %%
import torch
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim

# %%
import torchfunc
import flowDataset
from torch.utils.data.sampler import SubsetRandomSampler

# %%
torch.__version__
torchfunc.cuda.reset()
torch.cuda.empty_cache()

# %% [markdown]
# ### 2. Create PyTorch data generators

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize
    ]),
}

# %%
dataset = flowDataset.flowDataset(data_transforms['train'])

# %%
batch_size = 50
validation_split = .2
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
test_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler)

# %%
dataloaders = {
    'train': train_loader,
    'validation': test_loader
}

# %% [markdown]
# ### 3. Create the network

# %%
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
device = torch.device("cuda:0")

# %%
model = models.resnet50(pretrained=True).to(device)
    
for param in model.parameters():
    param.requires_grad = False   
    
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 7)).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters())

# %% [markdown]
# ### 4. Train the model

# %%
def train_model(model, criterion, optimizer, num_epochs=3):
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.detach() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase])
            epoch_acc = running_corrects.float() / len(dataloaders[phase])

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase, epoch_loss.item(), epoch_acc.item()))
    return model

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=100)
# Out:
# Epoch 1/100
# ----------
# C:\Users\reese\miniconda3\envs\final-year-project\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# train loss: 63.5342, acc: 20.5455
# validation loss: 66.0860, acc: 19.3333
# Epoch 2/100
# ----------
# train loss: 50.0220, acc: 27.7273
# validation loss: 52.7948, acc: 19.0000
# Epoch 3/100
# ----------
# train loss: 40.7447, acc: 31.0909
# validation loss: 40.0022, acc: 29.6667
# Epoch 4/100
# ----------
# train loss: 35.8912, acc: 33.1818
# validation loss: 36.0039, acc: 29.3333
# Epoch 5/100
# ----------
# train loss: 31.9922, acc: 34.8182
# validation loss: 32.8497, acc: 29.3333
# Epoch 6/100
# ----------
# train loss: 30.9717, acc: 35.8182
# validation loss: 32.3724, acc: 30.3333
# Epoch 7/100
# ----------
# train loss: 29.9535, acc: 35.3636
# validation loss: 28.1005, acc: 32.6667
# Epoch 8/100
# ----------
# train loss: 27.6415, acc: 36.0909
# validation loss: 31.9299, acc: 30.0000
# Epoch 9/100
# ----------
# train loss: 29.9910, acc: 35.0000
# validation loss: 28.5550, acc: 32.3333
# Epoch 10/100
# ----------
# train loss: 26.7880, acc: 36.7273
# validation loss: 29.7279, acc: 31.3333
# Epoch 11/100
# ----------
# train loss: 26.0020, acc: 36.3636
# validation loss: 28.5076, acc: 33.0000
# Epoch 12/100
# ----------
# train loss: 26.2979, acc: 35.8182
# validation loss: 28.6067, acc: 33.6667
# Epoch 13/100
# ----------
# train loss: 29.1907, acc: 34.8182
# validation loss: 32.5957, acc: 30.3333
# Epoch 14/100
# ----------
# train loss: 32.1402, acc: 32.4545
# validation loss: 26.3686, acc: 32.3333
# Epoch 15/100
# ----------
# train loss: 30.3559, acc: 34.4545
# validation loss: 33.0002, acc: 28.3333
# Epoch 16/100
# ----------
# train loss: 27.5093, acc: 34.8182
# validation loss: 43.8633, acc: 24.3333
# Epoch 17/100
# ----------
# train loss: 28.2273, acc: 34.0909
# validation loss: 25.3900, acc: 33.6667
# Epoch 18/100
# ----------
# train loss: 30.3381, acc: 34.0909
# validation loss: 23.9732, acc: 33.0000
# Epoch 19/100
# ----------
# train loss: 29.3272, acc: 34.5455
# validation loss: 27.2766, acc: 32.6667
# Epoch 20/100
# ----------
# train loss: 25.6270, acc: 36.1818
# validation loss: 30.1399, acc: 30.6667
# Epoch 21/100
# ----------
# train loss: 24.1881, acc: 37.0909
# validation loss: 27.1583, acc: 31.3333
# Epoch 22/100
# ----------
# train loss: 24.6402, acc: 36.7273
# Epoch 82/100
# ----------
# train loss: 19.3670, acc: 39.2727
# validation loss: 23.3921, acc: 34.0000
# Epoch 83/100
# ----------
# train loss: 19.7189, acc: 38.7273
# validation loss: 28.6765, acc: 34.3333
# Epoch 84/100
# ----------
# train loss: 22.5369, acc: 36.7273
# validation loss: 28.9835, acc: 33.6667
# Epoch 85/100
# ----------
# train loss: 22.1341, acc: 37.3636
# validation loss: 23.1422, acc: 32.6667
# Epoch 86/100
# ----------
# train loss: 22.2806, acc: 37.3636
# validation loss: 19.1769, acc: 35.6667
# Epoch 87/100
# ----------
# train loss: 20.9344, acc: 38.2727
# validation loss: 26.6931, acc: 34.0000
# Epoch 88/100
# ----------
# train loss: 22.7059, acc: 37.0909
# validation loss: 23.1794, acc: 34.3333
# Epoch 89/100
# ----------
# train loss: 19.8062, acc: 38.8182
# validation loss: 23.0372, acc: 32.6667
# Epoch 90/100
# ----------
# train loss: 20.7191, acc: 38.0000
# validation loss: 24.9244, acc: 33.6667
# Epoch 91/100
# ----------
# train loss: 21.0671, acc: 37.7273
# validation loss: 22.2046, acc: 34.0000
# Epoch 92/100
# ----------
# train loss: 17.6466, acc: 39.0000
# validation loss: 27.8832, acc: 33.6667
# Epoch 93/100
# ----------
# train loss: 20.0960, acc: 38.4545
# validation loss: 24.8872, acc: 32.3333
# Epoch 94/100
# ----------
# train loss: 22.9860, acc: 36.6364
# validation loss: 26.6037, acc: 32.6667
# Epoch 95/100
# ----------
# train loss: 18.7099, acc: 39.2727
# validation loss: 21.3248, acc: 34.6667
# Epoch 96/100
# ----------
# train loss: 21.0093, acc: 37.4545
# validation loss: 21.0922, acc: 34.3333
# Epoch 97/100
# ----------
# train loss: 19.4397, acc: 39.3636
# validation loss: 21.1657, acc: 33.6667
# Epoch 98/100
# ----------
# train loss: 22.3433, acc: 38.0000
# validation loss: 25.4559, acc: 32.3333
# Epoch 99/100
# ----------
# train loss: 19.1169, acc: 39.0000
# validation loss: 23.8019, acc: 33.3333
# Epoch 100/100
# ----------
# train loss: 19.7480, acc: 39.1818
# validation loss: 20.8259, acc: 34.6667

# %% [markdown]
# ### 5. Save and load the model

# %%
torch.save(model_trained.state_dict(), 'models/pytorch/weights.h5')

# %%
model = models.resnet50(pretrained=False).to(device)
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 7)).to(device)
model.load_state_dict(torch.load('models/pytorch/weights.h5'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### 6. Make predictions on sample test images

# %%
validation_img_paths = ["D:/Flow Videos/dataset/frame_64.jpg",
                        "D:/Flow Videos/dataset/frame_536.jpg",
                        "D:/Flow Videos/dataset/frame_450.jpg"]
img_list = [Image.open(img_path) for img_path in validation_img_paths]

# %%
validation_batch = torch.stack([data_transforms['validation'](img).to(device)
                                for img in img_list])

# %%
pred_logits_tensor = model(validation_batch)
pred_probs = F.softmax(pred_logits_tensor, dim=1).cpu().data.numpy()

# %%
fig, axs = plt.subplots(1, len(img_list), figsize=(20, 5))
for i, img in enumerate(img_list):
    ax = axs[i]
    ax.axis('off')
    ax.set_title("{:.0f}% bub, {:.0f}% bub-sl,{:.0f}% sl, {:.0f}% sl-ch, {:.0f}% ch, {:.0f}% ch-ann, {:.0f}% ann".format(
    100*pred_probs[i,0], 100*pred_probs[i,1],100*pred_probs[i,2],100*pred_probs[i,3],100*pred_probs[i,4],100*pred_probs[i,5],100*pred_probs[i,6]))
    ax.imshow(img)
